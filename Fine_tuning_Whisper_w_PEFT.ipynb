# %% [markdown]
# # Fine-tune Whisper (large) with LoRA & BNB powerd by PEFT ⚡️

# %% [markdown]
# A one size fits all notebook, to fine-tune Whisper (large) on a consumer GPU with less than 8GB GPU VRAM, all with comparable performance to full-finetuning. ⚡️
#
# We present a step-by-step guide on how to fine-tune Whisper with Common Voice 13.0 dataset using 🤗 Transformers and PEFT. In this Colab, we leverage `PEFT` and `bitsandbytes` to train a `whisper-large-v2` checkpoint seamlessly with a free T4 GPU (16 GB VRAM).
#
# For more details on Whisper fine-tuning, datasets and metrics, refer to Sanchit Gandhi's brilliant blogpost: [Fine-Tune Whisper For Multilingual ASR with 🤗 Transformers](https://huggingface.co/blog/fine-tune-whisper)
#
# ## Why Parameter Efficient Fine Tuning ([PEFT](https://github.com/huggingface/peft))?
#
# As the model size continue to increase, fine tuning a model has become both computationally expensive and storage heavy. For example, a `Whisper-large-v2` model requires ~24GB of GPU VRAM to fine-tune for full fine-tuning and requires ~7 GB of storage for each fine-tuned storage. For low-resource environments this becomes quite a bottleneck and often near impossible to get meaningful results.
#
# Cue, PEFT, with PEFT you can tackle this bottleneck head on. PEFT approaches (like Low Rank Adaptation) only fine-tune a small number of (extra) model parameters while freezing most parameters of the pretrained model, thereby greatly decreasing the computational and storage costs. We've observed that it also overcomes the issues of catastrophic forgetting, a behaviour observed during the full finetuning of large models.
#
# ### Aha! So wait, what's this LoRA thing?
#
# PEFT comes out-of-the-box with multiple parameter efficient techniques. One such technique is [Low Rank Adaptation or LoRA](https://github.com/microsoft/LoRA). LoRA freezes the pre-trained model weights and injects trainable rank decomposition matrices into each layer of the Transformer architecture. This greatly reduces the number of trainable parameters for downstream tasks.
#
# LoRA performs on-par or better than fine-tuning in model quality despite having fewer trainable parameters, a higher training throughput, and, unlike adapters, no additional inference latency.
#
# ### That's all cool, but show me the numbers?
#
# Don't worry, we got ya! We ran multiple experiments to compare a full fine-tuning of Whisper-large-v2 checkpoint and that with PEFT, here's what we found:
#
# 1. We were able to fine-tune a 1.6B parameter model with less than 8GB GPU VRAM. 🤯
# 2. With significantly less number of traininable parameters, we were able to fit almost **5x** more batch size. 📈
# 3. The resultant checkpoint were less than 1% the size of the original model, ~60MB (i.e. 1% the size of orignal model) 🚀
#
# To make things even better, all of this comes with minimal changes to the existing 🤗 transformers Whisper inference codebase.
#
# ### Curious to test this out for yourself? Follow along!

# %% [markdown]
# ## Prepare Environment
#
# We'll employ several popular Python packages to fine-tune the Whisper model.
# We'll use `datasets` to download and prepare our training data and
# `transformers` to load and train our Whisper model. We'll also require
# the `librosa` package to pre-process audio files, `evaluate` and `jiwer` to
# assess the performance of our model. Finally, we'll
# use `PEFT`, `bitsandbytes`, `accelerate` to prepare and fine-tune the model with LoRA.

# %% [markdown]
# #### How to save a locally created audio dataset

# %%
from datasets import load_dataset, DatasetDict, Audio

# Load your CSV file
data_files = {"train": "path/to/your/csvfile.csv"}
dataset = load_dataset("csv", data_files=data_files)

# Cast the 'path' column to Audio
dataset = dataset.cast_column("path", Audio(sampling_rate=16000))

# Rename the 'path' column to 'audio' for clarity
dataset = dataset.rename_column("path", "audio")

# Print the dataset to verify
print(dataset)

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !rm -rf ~/.cache/huggingface/hub/

# %%
# !rm -rf ~/.cache/huggingface/datasets/

# %%
# !ls -lh ~/.cache/huggingface/

# %%
# !pip install -q transformers datasets librosa evaluate jiwer gradio bitsandbytes==0.37 accelerate
# !pip install -q git+https://github.com/huggingface/peft.git@main

# %% [markdown]
# With the environment now set up, let's try to secure a decent GPU for our Colab! Unfortunately, it's becoming much harder to get access to a good GPU with the free version of Google Colab. However, with Google Colab Pro one should have no issues in being allocated a V100 or P100 GPU.
#
# To get a GPU, click _Runtime_ -> _Change runtime type_, then change _Hardware accelerator_ from _None_ to _GPU_.
#
# We can verify that we've been assigned a GPU and view its specifications:

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

# %% [markdown]
# Alrighty! Let's configure our environment to ensure it uses the GPU provided by Colab to us.

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %% [markdown]
# We strongly advise you to upload model checkpoints directly the [Hugging Face Hub](https://huggingface.co/)
# whilst training. The Hub provides:
# - Integrated version control: you can be sure that no model checkpoint is lost during training.
# - Tensorboard logs: track important metrics over the course of training.
# - Model cards: document what a model does and its intended use cases.
# - Community: an easy way to share and collaborate with the community!
#
# Linking the notebook to the Hub is straightforward - it simply requires entering your Hub authentication token when prompted. Find your Hub authentication token [here](https://huggingface.co/settings/tokens):

# %%
from huggingface_hub import login
token="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"

login(token=token)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to C:\Users\PC\.cache\huggingface\token
# Login successful

# %% [markdown]
# Next up, we define Whisper model checkpoints and task details.

# %%
model_name_or_path = "openai/whisper-tiny"
task = "transcribe"

# %% [markdown]
# Lastly, we define the dataset details, including the language we'd like to fine-tune Whisper on too.

# %%
dataset_name = "mozilla-foundation/common_voice_13_0"
language = "marathi"
language_abbr = "mr" # Short hand code for the language we want to fine-tune

# %% [markdown]
# # Load Dataset
#
# Using 🤗 Datasets, downloading and preparing data is extremely simple.
# We can download and prepare the Common Voice splits in just one line of code.
#
# First, ensure you have accepted the terms of use on the Hugging Face Hub: [mozilla-foundation/common_voice_13_0](https://huggingface.co/datasets/mozilla-foundation/common_voice_13_0). Once you have accepted the terms, you will have full access to the dataset and be able to download the data locally.
#
# Since Hindi is very low-resource, we'll combine the `train` and `validation`
# splits to give approximately 12 hours of training data. We'll use the 6 hours
# of `test` data as our held-out test set:

# %%
from datasets import load_dataset, DatasetDict

common_voice = DatasetDict()

common_voice["train"] = load_dataset(dataset_name, language_abbr, split="train+validation", use_auth_token=True, trust_remote_code=True)
common_voice["test"] = load_dataset(dataset_name, language_abbr, split="test", use_auth_token=True, trust_remote_code=True)

print(common_voice)
# Out:
# c:\Users\PC\Documents\Speech2Text\myenv\lib\site-packages\datasets\load.py:2566: FutureWarning: 'use_auth_token' was deprecated in favor of 'token' in version 2.14.0 and will be removed in 3.0.0.
# You can remove this warning by passing 'token=<use_auth_token>' instead.
#   warnings.warn(
# c:\Users\PC\Documents\Speech2Text\myenv\lib\site-packages\datasets\load.py:2566: FutureWarning: 'use_auth_token' was deprecated in favor of 'token' in version 2.14.0 and will be removed in 3.0.0.
# You can remove this warning by passing 'token=<use_auth_token>' instead.
#   warnings.warn(
# DatasetDict({
#     train: Dataset({
#         features: ['client_id', 'path', 'audio', 'sentence', 'up_votes', 'down_votes', 'age', 'gender', 'accent', 'locale', 'segment', 'variant'],
#         num_rows: 4009
#     })
#     test: Dataset({
#         features: ['client_id', 'path', 'audio', 'sentence', 'up_votes', 'down_votes', 'age', 'gender', 'accent', 'locale', 'segment', 'variant'],
#         num_rows: 1735
#     })
# })

# %% [markdown]
# Most ASR datasets only provide input audio samples (`audio`) and the
# corresponding transcribed text (`sentence`). Common Voice contains additional
# metadata information, such as `accent` and `locale`, which we can disregard for ASR.
# Keeping the notebook as general as possible, we only consider the input audio and
# transcribed text for fine-tuning, discarding the additional metadata information:

# %%
common_voice = common_voice.remove_columns(
    ["accent", "age", "client_id", "down_votes", "gender", "locale", "path", "segment", "up_votes","variant"]
)

print(common_voice)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['audio', 'sentence'],
#         num_rows: 4009
#     })
#     test: Dataset({
#         features: ['audio', 'sentence'],
#         num_rows: 1735
#     })
# })

# %% [markdown]
# ## Prepare Feature Extractor, Tokenizer and Data
#
# The ASR pipeline can be de-composed into three stages:
# 1. A feature extractor which pre-processes the raw audio-inputs
# 2. The model which performs the sequence-to-sequence mapping
# 3. A tokenizer which post-processes the model outputs to text format
#
# In 🤗 Transformers, the Whisper model has an associated feature extractor and tokenizer,
# called [WhisperFeatureExtractor](https://huggingface.co/docs/transformers/main/model_doc/whisper#transformers.WhisperFeatureExtractor)
# and [WhisperTokenizer](https://huggingface.co/docs/transformers/main/model_doc/whisper#transformers.WhisperTokenizer)
# respectively.

# %%
from transformers import WhisperFeatureExtractor

feature_extractor = WhisperFeatureExtractor.from_pretrained(model_name_or_path)

# %%
from transformers import WhisperTokenizer

tokenizer = WhisperTokenizer.from_pretrained(model_name_or_path, language=language, task=task)

# %% [markdown]
# To simplify using the feature extractor and tokenizer, we can _wrap_ both into a single `WhisperProcessor` class. This processor object can be used on the audio inputs and model predictions as required.
# In doing so, we only need to keep track of two objects during training:
# the `processor` and the `model`:

# %%
from transformers import WhisperProcessor

processor = WhisperProcessor.from_pretrained(model_name_or_path, language=language, task=task)

# %% [markdown]
# ### Prepare Data
#
# Let's print the first example of the Common Voice dataset to see
# what form the data is in:

# %%
print(common_voice["train"][0])

# %% [markdown]
# Since
# our input audio is sampled at 48kHz, we need to _downsample_ it to
# 16kHz prior to passing it to the Whisper feature extractor, 16kHz being the sampling rate expected by the Whisper model.
#
# We'll set the audio inputs to the correct sampling rate using dataset's
# [`cast_column`](https://huggingface.co/docs/datasets/package_reference/main_classes.html?highlight=cast_column#datasets.DatasetDict.cast_column)
# method. This operation does not change the audio in-place,
# but rather signals to `datasets` to resample audio samples _on the fly_ the
# first time that they are loaded:

# %%
from datasets import Audio

common_voice = common_voice.cast_column("audio", Audio(sampling_rate=16000))

# %% [markdown]
# Re-loading the first audio sample in the Common Voice dataset will resample
# it to the desired sampling rate:

# %%
print(common_voice["train"][0])

# %% [markdown]
# Now we can write a function to prepare our data ready for the model:
# 1. We load and resample the audio data by calling `batch["audio"]`. As explained above, 🤗 Datasets performs any necessary resampling operations on the fly.
# 2. We use the feature extractor to compute the log-Mel spectrogram input features from our 1-dimensional audio array.
# 3. We encode the transcriptions to label ids through the use of the tokenizer.

# %%
def prepare_dataset(batch, feature_extractor, tokenizer):
    # load and resample audio data from 48 to 16kHz
    audio = batch["audio"]

    # compute log-Mel input features from input audio array
    batch["input_features"] = feature_extractor(audio["array"], sampling_rate=audio["sampling_rate"]).input_features[0]

    # encode target text to label ids
    batch["labels"] = tokenizer(batch["sentence"]).input_ids
    return batch

# %% [markdown]
# We can apply the data preparation function to all of our training examples using dataset's `.map` method. The argument `num_proc` specifies how many CPU cores to use. Setting `num_proc` > 1 will enable multiprocessing. If the `.map` method hangs with multiprocessing, set `num_proc=1` and process the dataset sequentially.
#
# Make yourself some tea 🍵, depending on dataset size, this might take 20-30 minutes ⏰

# %%
# common_voice = common_voice.map(prepare_dataset, remove_columns=common_voice.column_names["train"], num_proc=2)
# Apply the function to the dataset
common_voice = common_voice.map(lambda batch: prepare_dataset(batch, feature_extractor, tokenizer),
                                remove_columns=common_voice.column_names["train"],num_proc=1)

# %%
common_voice["train"]

# %% [markdown]
# ## Training and Evaluation
#
# Now that we've prepared our data, we're ready to dive into the training pipeline.
# The [🤗 Trainer](https://huggingface.co/transformers/master/main_classes/trainer.html?highlight=trainer)
# will do much of the heavy lifting for us. All we have to do is:
#
# - Define a data collator: the data collator takes our pre-processed data and prepares PyTorch tensors ready for the model.
#
# - Evaluation metrics: during evaluation, we want to evaluate the model using the [word error rate (WER)](https://huggingface.co/metrics/wer) metric.
#
# - Load a pre-trained checkpoint: we need to load a pre-trained checkpoint and configure it correctly for training.
#
# - Define the training configuration: this will be used by the 🤗 Trainer to define the training schedule.
#
# Once we've fine-tuned the model, we will evaluate it on the test data to verify that we have correctly trained it
# to transcribe speech in Hindi.

# %% [markdown]
# ### Define a Data Collator
#
# The data collator for a sequence-to-sequence speech model is unique in the sense that it
# treats the `input_features` and `labels` independently: the  `input_features` must be
# handled by the feature extractor and the `labels` by the tokenizer.
#
# The `input_features` are already padded to 30s and converted to a log-Mel spectrogram
# of fixed dimension by action of the feature extractor, so all we have to do is convert the `input_features`
# to batched PyTorch tensors. We do this using the feature extractor's `.pad` method with `return_tensors=pt`.
#
# The `labels` on the other hand are un-padded. We first pad the sequences
# to the maximum length in the batch using the tokenizer's `.pad` method. The padding tokens
# are then replaced by `-100` so that these tokens are **not** taken into account when
# computing the loss. We then cut the BOS token from the start of the label sequence as we
# append it later during training.
#
# We can leverage the `WhisperProcessor` we defined earlier to perform both the
# feature extractor and the tokenizer operations:

# %%
import torch

from dataclasses import dataclass
from typing import Any, Dict, List, Union


@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lengths and need different padding methods
        # first treat the audio inputs by simply returning torch tensors
        input_features = [{"input_features": feature["input_features"]} for feature in features]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        # get the tokenized label sequences
        label_features = [{"input_ids": feature["labels"]} for feature in features]
        # pad the labels to max length
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        # if bos token is appended in previous tokenization step,
        # cut bos token here as it's append later anyways
        if (labels[:, 0] == self.processor.tokenizer.bos_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels

        return batch

# %% [markdown]
# Let's initialise the data collator we've just defined:

# %%
data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)

# %% [markdown]
# ### Evaluation Metrics

# %% [markdown]
# We'll use the word error rate (WER) metric, the 'de-facto' metric for assessing
# ASR systems. For more information, refer to the WER [docs](https://huggingface.co/metrics/wer). We'll load the WER metric from 🤗 Evaluate:

# %%
import evaluate

metric = evaluate.load("wer")
# Out:
# Downloading builder script:   0%|          | 0.00/4.49k [00:00<?, ?B/s]

# %% [markdown]
# ### Load a Pre-Trained Checkpoint

# %% [markdown]
# Now let's load the pre-trained Whisper checkpoint. Again, this
# is trivial through use of 🤗 Transformers!
#
# To reduce our models memory footprint, we load the model in 8bit, this means we quantize the model to use 1/4th precision (when comapared to float32) with minimal loss to performance. To read more about how this works, head over [here](https://huggingface.co/blog/hf-bitsandbytes-integration).

# %%
# !pip install bitsandbytes --upgrade

# %%
from transformers import WhisperForConditionalGeneration

model = WhisperForConditionalGeneration.from_pretrained(model_name_or_path, load_in_8bit=True, device_map="auto")

# %% [markdown]
# ### Post-processing on the model
#
# Finally, we need to apply some post-processing steps on the 8-bit model to enable training. We do so by first freezing all the model layers, and then cast the layer-norm and the output layer in `float32` for training and model stability.

# %%
# !pip install peft --upgrade

# %%
from peft import prepare_model_for_kbit_training

model = prepare_model_for_kbit_training(model)

# %% [markdown]
# Since the Whisper model uses Convolutional layers in the Encoder, checkpointing disables grad computation to avoid this we specifically need to make the inputs trainable.

# %%
def make_inputs_require_grad(module, input, output):
    output.requires_grad_(True)

model.model.encoder.conv1.register_forward_hook(make_inputs_require_grad)

# %% [markdown]
# ### Apply Low-rank adapters (LoRA) to the model
#
# Here comes the magic with `peft`! Let's load a `PeftModel` and specify that we are going to use low-rank adapters (LoRA) using `get_peft_model` utility function from `peft`.

# %%
from peft import LoraConfig, PeftModel, LoraModel, LoraConfig, get_peft_model

config = LoraConfig(r=32, lora_alpha=64, target_modules=["q_proj", "v_proj"], lora_dropout=0.05, bias="none")

model = get_peft_model(model, config)
model.print_trainable_parameters()

# %% [markdown]
# We are ONLY using **1%** of the total trainable parameters, thereby performing **Parameter-Efficient Fine-Tuning**

# %% [markdown]
# ### Define the Training Configuration

# %% [markdown]
# In the final step, we define all the parameters related to training. For more detail on the training arguments, refer to the Seq2SeqTrainingArguments [docs](https://huggingface.co/docs/transformers/main_classes/trainer#transformers.Seq2SeqTrainingArguments).

# %%
from transformers import Seq2SeqTrainingArguments

training_args = Seq2SeqTrainingArguments(
    output_dir="reach-vb/test",  # change to a repo name of your choice
    per_device_train_batch_size=8,
    gradient_accumulation_steps=1,  # increase by 2x for every 2x decrease in batch size
    learning_rate=1e-3,
    warmup_steps=50,
    num_train_epochs=1,
    evaluation_strategy="steps",
    fp16=True,
    per_device_eval_batch_size=8,
    generation_max_length=128,
    logging_steps=100,
    max_steps=100, # only for testing purposes, remove this from your final run :)
    remove_unused_columns=False,  # required as the PeftModel forward doesn't have the signature of the wrapped model's forward
    label_names=["labels"],  # same reason as above
)

# %% [markdown]
# Fine-tuning a model with PEFT comes with a few caveats.
#
# 1. We need to explicitly set `remove_unused_columns=False` and `label_names=["labels"]` as the PeftModel's forward doesn't inherit the signature of the base model's forward.
#
# 2. Since INT8 training requires autocasting, we cannot use the native `predict_with_generate` call in Trainer as it doesn't automatically cast.
#
# 3. Similarly, since we cannot autocast, we cannot pass the `compute_metrics` to `Seq2SeqTrainer` so we'll comment it out whilst instantiating the Trainer.

# %%
import os
from transformers import Seq2SeqTrainer, TrainerCallback, TrainingArguments, TrainerState, TrainerControl
from transformers.trainer_utils import PREFIX_CHECKPOINT_DIR

# This callback helps to save only the adapter weights and remove the base model weights.
class SavePeftModelCallback(TrainerCallback):
    def on_save(
        self,
        args: TrainingArguments,
        state: TrainerState,
        control: TrainerControl,
        **kwargs,
    ):
        checkpoint_folder = os.path.join(args.output_dir, f"{PREFIX_CHECKPOINT_DIR}-{state.global_step}")

        peft_model_path = os.path.join(checkpoint_folder, "adapter_model")
        kwargs["model"].save_pretrained(peft_model_path)

        pytorch_model_path = os.path.join(checkpoint_folder, "pytorch_model.bin")
        if os.path.exists(pytorch_model_path):
            os.remove(pytorch_model_path)
        return control


trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=common_voice["train"],
    eval_dataset=common_voice["test"],
    data_collator=data_collator,
    # compute_metrics=compute_metrics,
    tokenizer=processor.feature_extractor,
    callbacks=[SavePeftModelCallback],
)
model.config.use_cache = False  # silence the warnings. Please re-enable for inference!

# %%
trainer.train()

# %% [markdown]
# Now that our model is fine-tuned, we can push the model on to Hugging Face Hub, this will later help us directly infer the model from the model repo.

# %%
peft_model_id = "Anudeep28/whisper-tiny-marathi-100steps"
model.push_to_hub(peft_model_id)

# %% [markdown]
# # Evaluation and Inference

# %% [markdown]
# On to the fun part, we've successfully fine-tuned our model. Now let's put it to test and calculate the WER on the `test` set.
#
# As with training, we do have a few caveats to pay attention to:
# 1. Since we cannot use `predict_with_generate` function, we will hand roll our own eval loop with `torch.cuda.amp.autocast()` you can check it out below.
# 2. Since the base model is frozen, PEFT model sometimes fails to recognise the language while decoding. To fix that, we force the starting tokens to mention the language we are transcribing. This is done via `forced_decoder_ids = processor.get_decoder_prompt_ids(language="Marathi", task="transcribe")` and passing that too the `model.generate` call.
#
# That's it, let's get transcribing! 🔥

# %%
from peft import PeftModel, PeftConfig
from transformers import WhisperForConditionalGeneration, Seq2SeqTrainer

peft_model_id = "Anudeep28/whisper-tiny-marathi-100steps" # Use the same model ID as before.
peft_config = PeftConfig.from_pretrained(peft_model_id)
model = WhisperForConditionalGeneration.from_pretrained(
    peft_config.base_model_name_or_path, load_in_8bit=True, device_map="auto"
)
model = PeftModel.from_pretrained(model, peft_model_id)
model.config.use_cache = True
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# adapter_model.safetensors:   0%|          | 0.00/2.37M [00:00<?, ?B/s]

# %%
import gc
import numpy as np
from tqdm import tqdm
from torch.utils.data import DataLoader
from transformers.models.whisper.english_normalizer import BasicTextNormalizer

eval_dataloader = DataLoader(common_voice["test"], batch_size=8, collate_fn=data_collator)
forced_decoder_ids = processor.get_decoder_prompt_ids(language=language, task=task)
normalizer = BasicTextNormalizer()

predictions = []
references = []
normalized_predictions = []
normalized_references = []

model.eval()
for step, batch in enumerate(tqdm(eval_dataloader)):
    with torch.cuda.amp.autocast():
        with torch.no_grad():
            generated_tokens = (
                model.generate(
                    input_features=batch["input_features"].to("cuda"),
                    forced_decoder_ids=forced_decoder_ids,
                    max_new_tokens=255,
                )
                .cpu()
                .numpy()
            )
            labels = batch["labels"].cpu().numpy()
            labels = np.where(labels != -100, labels, processor.tokenizer.pad_token_id)
            decoded_preds = processor.tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)
            decoded_labels = processor.tokenizer.batch_decode(labels, skip_special_tokens=True)
            predictions.extend(decoded_preds)
            references.extend(decoded_labels)
            normalized_predictions.extend([normalizer(pred).strip() for pred in decoded_preds])
            normalized_references.extend([normalizer(label).strip() for label in decoded_labels])
        del generated_tokens, labels, batch
    gc.collect()
wer = 100 * metric.compute(predictions=predictions, references=references)
normalized_wer = 100 * metric.compute(predictions=normalized_predictions, references=normalized_references)
eval_metrics = {"eval/wer": wer, "eval/normalized_wer": normalized_wer}

print(f"{wer=} and {normalized_wer=}")
print(eval_metrics)
# Out:
#   0%|          | 0/217 [00:00<?, ?it/s]C:\Users\PC\AppData\Local\Temp\ipykernel_18452\3471926970.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# c:\Users\PC\Documents\Speech2Text\myenv\lib\site-packages\bitsandbytes\autograd\_functions.py:316: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# c:\Users\PC\Documents\Speech2Text\myenv\lib\site-packages\transformers\models\whisper\modeling_whisper.py:598: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# 100%|██████████| 217/217 [16:58<00:00,  4.69s/it]
# wer=69.44313514241465 and normalized_wer=33.445487872244264
# {'eval/wer': 69.44313514241465, 'eval/normalized_wer': 33.445487872244264}

# %%
for org,pred in zip(references,predictions):
    print(f"actual: {org} | Pred: {pred}")
# Out:
# actual: स्वेच्छानिवृतीचा पध्दत मोठ्या प्रमाणात अंमलात आल्यापासून या दुखण्याने अनेक घरांत प्रवेश केला आहे. | Pred: श्वेच्चान द्रौट्ध पद्धात म्हट्या प्रमणात आमळात अभवात अन्ला बजोत न्हा दुपण्याने अनेकरात प्रविश केला आहे.
# actual: गोविंदपंत व मीराबाई हे त्यांचे आजोबा आजी होत. | Pred: गोविंट पंतव मिरापाही हे त्यांचे आजबा आज्ये होत.
# actual: आपण काम करतो त्या गावात अलिशान घर न बांधणं. | Pred: आपण काम घरतोत्या गावात आलिशान घर्ण बाणणा.
# actual: रावणाला संगीताची आवड होती. | Pred: भाळणाला संघेताचे आवड होते.
# actual: चारुता सागर दिनकर दत्तात्रेय भोसले | Pred: चारोता सागातिंकाळ दतात्रेव बोसले.
# actual: खमंग वास येतोय. | Pred: पर्णद वास येवर आ
# actual: कर्ज म्हणजे जिवंतपणीचा नरक होय. | Pred: कर्जमणजे जिवनतपणीचूनरोख होल.
# actual: हेच त्यांचे कौटुंबिक मंदिर होय. | Pred: हेच त्यांचे कौतूंपिक मंदिर होत.
# actual: ब्रिटिश सैनिकाला भारतीय सैनिकापेक्षा अधिक सोयीसुविधा व पगार दिला जात असे. | Pred: ब्रिटिस सेनिकाला भारतीय सानिकापेक्षा अधिक सोळी सुविधा व पगार दिला जात असे.
# actual: माणसाने माणसाशी माणसासारखं वागणं गरजेचं असतं. | Pred: माणसानी माळत साशी माणसासारखवागण गर्जेच असतो.
# actual: आदरार्थी शब्दांनी केला जात असे लहानपणी गंगेजवळ असताना वसिष्ठांनी त्यांना सर्व वेद शिकविले होते. | Pred: आदरार्थी शब्दांनी केला जात असेलाहातपणी गंगेजवळ असताना वसिष्ठांनी त्यांनासर्ववेचिकवीले होते.
# actual: त्यातील एर्देनि हे रत् नाचे व सुबाशिदि हे सुभाषिताचे मंगोलियन भाषारूप होय. | Pred: त्यातील एदेरणी हे रतनाचे व सुभाषिदी हे सुभाषिताचे मंगोल्यांभाषारूप होई.
# actual: क्रोष्टु, सहस्रजित्, नल, अंतिक व लघु अशी त्याच्या पुत्रांची नावे आढळतात. | Pred: प्रोष्टू, सहस्त्रजीत, नलव अंतिक व लघू अशी त्याच्या पुत्रांची नावे आढळतात.
# actual: चार चार विषय आहेत. | Pred: चारचारवीशय आहेत.
# actual: त्याच्या जुळ्या भावाचे नाव कुश असे होते. | Pred: त्याच्या जुळ्या भावाचे नाव कुष असे होते.
# actual: प्रकाश संश्लेषण या क्रियेत वनस्पती सूर्यप्रकाश शोषून ती उर्जा रसायनिक उर्जेत परिवर्तीत करतात. | Pred: प्रकाश संशले शणि याक्रीयत वनस्वती सुर्यप्रकाश शून ती गुर्जार रसाहिनेकुर्जेक परीवर्तित करतात.
# actual: याच्या विषारी फुत्कारांमुळे यमुनेचे पाणी विषारी झाले होते. | Pred: याच्या विष्टारी पुतकारांमुळे यमुणेचे पाणी विष्टारी झाले होते.
# actual: सद्यस्थितीत कर्नाटक आर्थिक बाबतीत भारतात पाचव्या क्रमांकावर आहे. | Pred: सद्यास्थीत कर्णाठा कार्थिक बापतीत भारतात पाच्व्या क्रमांकावर आहे.
# actual: या साखळीत एखाद्या प्रामाणिक माणसाचा शिरकाव झाला की, ती तुटण्याची शक्यता असते. | Pred: या साखळेत एखध्या प्रामाणिक मानसाता शिरकावधाला ती सुखण्याची शक्यात आसता.
# actual: ती म्हणजे समुद्र मंथन. | Pred: ई वणजे समोद्रमान घान.
# actual: आजही हा चित्रपट गर्दी खेचतो. | Pred: आणजही हाची द्धापट टर्धी घेशतो.
# actual: अकोला जिल्ह्यातील तालुके महाराष्ट्रातील तालुकेअकोला जिल्हा महाराष्ट्राच्या पूर्व भागात आहे. | Pred: अखणवाची म्हणण वानूके माराष्ट्रते तालूके अखणला जिल्हा म्हणव्हणा आजात आहे.
# actual: येथे दरवर्षी महिनाभर जत्रा चालते. | Pred: एथे जवरची मैळावर चंपलास अंपे.
# actual: हा विस्तार जवळजवळ आयर्लंड देशाइतका आहे. | Pred: हा विस्थास वळजवळ आवेयारल तयंड देशा एकका आहे.
# actual: त्यासाठी भारतभर भ्रमण केले. | Pred: चाप सठिठी मालत बळभ्यपाण केते.
# actual: हा भडकलेला वणवा आहे. | Pred: आभळड्या कील्ह्या वणवा आगे.
# actual: वग वग म्हणजे नाट्यरूपाने सादर केलेली कथा. | Pred: बाबबबबबबबबबबबबबबबण चेण आजदर केलेली करता.
# actual: या प्रसंगानंतरच संत नामदेवांना विसोबा खेचर हे आध्यात्मिक गुरू म्हणून लाभले. | Pred: याब प्रसंगानंतर्तच संतदांदेवांना विस्टोबाब हेच सव्हे आण्थ्यात मेक भूळो माणूने दाबने.
# actual: भारतातील राजकीय पक्षराष्ट्रीय जनता दल हा एक भारतातील राजकीय पक्ष आहे. | Pred: भारतातील राजकीय पक्षराष्ट्रीय जंतादलहा एक भारतातील राजकीय पक्ष आये.
# actual: कृष्णाने जे योजले होते ते पार पडले. | Pred: कृष्णाने जे योजले हते ते ते पार पडले.
# actual: त्यासाठी बरोबर खुणेवर टिचकी मारा. | Pred: त्यासाठी बरोबर, कुनेवर, इच्ती मळा.
# actual: मुंबई दिल्ली जयपूर उदयपूर आणि औरंगाबाद ह्या शहरांमधे सध्या विमानांची येजा असते. | Pred: मुंबई दिल्ले जयपूर उदयपुराण वरंगाबाद्या शरांमध्येज सद्ध्याव्यमानंची एजा असते.
# actual: परंतु श्रीकृष्णाने त्याला जीवन दिले. | Pred: परंतु श्रीकृष्णाने त्याला जिवंदीले.
# actual: म्हणून त्याने सूर्याच्या दिशेने झेप घेतली. | Pred: म्हणून त्याने सुर्याच्या दिशेने जेप घेतले.
# actual: याचे नाव गहिनीनाथ असे ठेव. | Pred: याचे नाव गहिंनात असे ठेव.
# actual: त्यांनी शून्य या अंकासठी ख या शब्दाचा वापर केला. | Pred: त्यांने शुन्ययांकांसटी खया शबदाचा वापरकेला.
# actual: त्यानुसार कृषी विद्यापीठातील शिक्षणक्रम राबविले जातात. | Pred: त्यानुसार कृषूव विद्ध्यापिटातील शिक्षण क्रम राभविले जातात.
# actual: थायलंडमध्ये रावणाचे शिल्प आढळते. | Pred: फायलंडमध्ये रावणाचे शिलप आढळते.
# actual: मी निर्दोष होत आहे. | Pred: मी निर्दश होता आये.
# actual: पण त्या संख्येची किमत व प्रत्येक अंकाची किमत मात्र वेगळी आहे. | Pred: पाळतासंखेची केमबत वाप्रप्तेख अंगाची किमबत मात्र वेगेय आहे.
# actual: तेथे त्यांनी एका शिळेवर सर्व ऋषींना बसवून उपदेश दिला. | Pred: तेथे त्यांने एका शेळ वरसर्व ऋषेंन बस्वूल उपदेश दिला.
# actual: तसेच काही वेळा इतर देवतांचे अवतार विष्णूंच्या अवतारांमध्ये गणले जातात. | Pred: तसेच काही वेळा इतर देवतांचे विष्णूनच्या अवतारांमध्ये गणले जातात.
# actual: शके सत्राशे दहापर्यंत ते प्रकटरूपाने फिरत होते. | Pred: शकेल सत्राशे दहापरंद ते प्रकट रुपाणी फिरत होते.
# actual: प्राथमिक शाळेच्या इयत्ता पहिली ते चौथीपर्यंतचे शिक्षण प्राथमिक शिक्षण म्हणून ओळखले जाते. | Pred: उप्राथमिक शाळेच्या येत्तापहीले तेचा उठीपरंथचे शिक्षण प्राथमिक शिक्षण म्हणून ओळखले जाते.
# actual: या शब्दाची उत्पत्ती ग्रीक भाषा शब्द किंवा या शब्दापासून झालेली आहे. | Pred: या शबधाची उत्पत्ती ग्रीक भाषा शबद किंवा या शबधापासून झालेरी आहे.
# actual: सृष्टिसौंदर्य पहायला व आयुर्वेदिक उपचारांसाठी देशातून तसेच जगभरातून हजारो प्रवासी केरळमध्ये येतात. | Pred: सृष्टी संदर्यपाहेला वायुर्वेदिक उपचारांसाठी देशातून तसेच जगभराटून हजारू प्रवाषी केरणमध्ये येतात.
# actual: भ्रष्टाचार्यांविरुद्ध न बिचकता कायदेशीर कारवाई करणंं. | Pred: भ्रिष्टाचार्यान विरूड्ध न पिचकता कायदीशीर कार्वायी करण
# actual: बरेचदा पर्वताचा माथा सपाट नसून सुळका अथवा शिखराच्या स्वरूपाचा असतो. | Pred: बरेजधा पर्वताचा माथा सपाटनसून सुळका अत्वा शिकराच्या स्वरूपाचा असतो.
# actual: अनेकांना बरोबर घेऊन जाईन. | Pred: अने कांना बरबर घेऊन जाहीन.
# actual: पोवाड्याचा उल्लेख ज्ञानेश्वरी मध्ये पवद असा केलेला आढळतो. | Pred: पोवाड्याचा उल्लेक न्यानिश्वरीमध्ये पवध असा केलेला आढलतो.
# actual: शंकराच्या अंगावरील भस्माइतकाच पवित्र झाला होता. | Pred: शंगराच्यंगावरील बसमाईतकाच पवित्रे झाला होता.
# actual: बहुधा पौराणिक कथांवर आधारलेले कूटप्रश्न एकमेकांना काव्यांतून विचारून त्यांची उत्तरे ओळखण्याचा हा कार्यक्रम असतो. | Pred: बहुता, पौराणिक कथांवर आधारलेले कुटप्रश्ण एक मिकांना कावव्यातून विचारून त्यांची उत्तरे उळकण्याचा हा कारेकरमशतो.
# actual: निदेशक, वैज्ञानिक व औद्योगिक संशोधन मंडळ | Pred: निदेशक वैज्ञानिक व अवद्योगीक संशोधन म्हणडल.
# actual: येथील चेरापुंजी हे गाव जगातील सर्वाधिक पाऊस पडणारे स्थान मानले जाते. | Pred: इथील चेरापूंची हे गाव जगातील सर्भादिक पाउसपण्नारे स्थान मानली जाती.
# actual: त्याला दशानन म्हणून ही ओळखतात. | Pred: त्याला दशानन म्हणून ही ओळकतात.
# actual: अनेक प्रेमगीतांमधून चंद्राचे उल्लेख आढळतात. | Pred: अनेख प्रेमुखितांमधून चंद्राचे उल्लेख आढळतात.
# actual: गोपीचंद्र व धर्मनाथ हे वैकुंठास गेले. | Pred: गोपी चंद्रवधर्मनात हे बैकुण टास गेले.
# actual: द्रोणाचार्य त्याच पावली परत फिरतात तेही सूडाचा निश्चय करून. | Pred: ध्रोणाचार्य त्याच पावली परत फिर्तात तेई रुडाचा निष्टणी घरुन.
# actual: त्यावेळी ते फक्त तीस वर्षांचे होते. | Pred: त्यावेळी ते फुत्तीस वाषाचे होते.
# actual: अटकपूर्व जामीन मिळाला आहे. | Pred: अटक पूर्व जामीन गिळाला आहे.
# actual: लहान मुले लामा होण्याचे प्रशिक्षण घेण्यासाठी मोनेस्ट्रीमध्येच राहतात. | Pred: लान मुले लामा होण्याचे पश्प्रशिक्षण घेण्यासाठी मोनेस्थीमध्ये राहतात.
# actual: हिडिंबा ही महाभारतात वर्णिलेली एक राक्षसी होती. | Pred: हेडींबाही महाभारतात वर्णिलेली एक राक्षसी होती.
# actual: किल्ला तसा फार मोठा नाही. | Pred: किल्ला तसाफहार मोठा गाही.
# actual: अनेक कौरवांना तो एकटाच भारी पडे. | Pred: अनेक कौरवांना तो एकटाच फारीपडत.
# actual: संधू मध्यमगती गोलंदाज होता. | Pred: संधू मध्यमगती गोलंदाच अहोता.
# actual: या शब्दाचा वर्णन करणे किंवा लिहिणे होतो. | Pred: या शब्दाच्या वर्णन कर्णे किवाली हिने होते.
# actual: याला कौसल्या, सुमित्रा व कैकेयी या तीन पत्नी होत्या. | Pred: याला कौसल्ल्ल्ल्ल सुमित्रा व कैके यातीन पत्नी होत्या.
# actual: शासकीय अभियांत्रिकी महाविद्यालय, अमरावती. | Pred: सासकीय अभियांतरिकी महाविद्यालय अमरावते.
# actual: जळगाव असे हो आमुचे जितके बेळगावही तितके एकमुखाने महाराष्ट्राचे गीत मराठी गाऊ। | Pred: जाळगाळ असेहो आमचे जितके बेळगावही तितके एकुमुखाने महाराष्ट्राचे गीत मराठी दाव.
# actual: यानंतर पद्य म्हणले जाते. | Pred: यानंतर पद्य म्हणले जाते.
# actual: राजा होण्याआधी त्याने काही लढायात भाग घेतला होता. | Pred: राजावण्याधी कंदेकायी लढायात भाग गेतला होता.
# actual: या रस्त्यांची बांधणी आणि देखभाल केंद्र सरकार करते. | Pred: या रस्त्यांची बांधणी आणि देखभाल केंद्र सर्कार करते.
# actual: निर्वाण महाभारतात कृष्णाच्या मृत्यूचे वर्णन आहे. | Pred: मिर्वान महाभारतात कृष्णाच्या मृत्तूचे वर्ण नासी.
# actual: याच गावाचे नाव नंतर विजयनगर म्हणून रूढ झाले. | Pred: याच गावाचे नावनंतर विजयन अगरमुनून रूड झाले.
# actual: समता पक्ष हा एक भारतातील राजकीय पक्ष आहे. | Pred: संता पक्षहा एका भारतातीलराजकीय पक्ष आहेत.
# actual: मागे एकदा पहाटे असाच आलो होतो. | Pred: मागे एकदा पहाठे असाच आलो होतो.
# actual: अनिरुद्ध पुनर्वसू खरे नाव नारायण आठवले | Pred: अनिरुद्ध पुनवर्सु खरे नाव नाराळ्य नाटवले.
# actual: ती गंगेला प्रयाग येथे येऊन मिळते. | Pred: ती गंगेला प्रया गेते यव निळते.
# actual: त्यांनी एकत्र प्रवासही केला. | Pred: त्यांनी एकत्र प्रवासही केला.
# actual: हा भाग बराचसा पठारी आहे. | Pred: हा भागभराचा पठारी आहे.
# actual: नैसर्गिक संरक्षण खारफुटीची वने व प्रवाळ बेटे नैसर्गिकरित्या त्सुनामीच्या तडाख्यांपासून भूपृष्ठाचे संरक्षण करतात. | Pred: नैसर्गेक सव्रक्षंखारफुटीची वणेवग प्रवाळ प्रटे नैसर्गिक ठ्रित्यासूना मिच्या तडाक्यांपत सून भूष्टाचे सव्रग्षंप्रातात.
# actual: भूकवचामध्ये अचानक कंपन होणे अथवा भूकवच अचानक काही क्षण हादरणे यास भूकंप म्हणतात. | Pred: भूकवच्या पमदे अचाना कंपन होणे अत्वाभूकवज अचाना कायक्षन हादरने यास भूकणप म्हणतात.
# actual: पोवाडे गाणाऱ्या कलाकारांस शाहीर म्हटले जाते. | Pred: पोवाडे गानार्या कलाकारा स्वाहीर मटले जाते.
# actual: रामायणातील व्यक्तिरेखामंथरा ही अयोध्येचा राजा राजा दशरथ याच्या कैकयी नावाच्या पत् नीची दासी होती. | Pred: रामायणातील वत्तिरेका मंत्राही अलेवद्देचा राजा राजा तश्रत याच्या कैकेळी नवाच्या पत्नीची दासी होती.
# actual: पंचांग फेस्टिव्हल्स ऑफ महाराष्ट्र सकाळ प्रकाशन, संकल्पना मृणाल पवार | Pred: पनच्यांकफेस्टीवजव प माराष्ट्रम सकाळ प्रकाशन संकळपणा मुणाल पवार.
# actual: वनवासी भिल्ल समाज वनात राहणारा, निसर्गप्रेमी आणि निसर्गाची काळजी वाहणारा म्हणून ओळखला जातो. | Pred: वंण्हासे भिलल समाजवनात रातात इसर्क प्रेमिणी लिसर्काची काळजी वांणारा मळण नळकला जोतो.
# actual: परंतु प्रत्यक्षात त्यांनी राज्याचा कधीच केला नाही. | Pred: परंतोप्रत्तिक्षात त्यानी राज्याचा कदीच केला नहे.
# actual: त्यांनी बालेघाटी लावणीला प्रतिष्ठा प्राप्त करून दिली. | Pred: त्यानी बाले खाटी व लावणीला प्रतीश्टा प्रप्त करून दिली.
# actual: खरे तर ती पांचाल राज्याची राजकन्या म्हणून तिला पांचाली म्हटले जात असे. | Pred: खरेतर ती पांच्याल राज्याची राजकना म्यंतीला पांचाली म्हटले जात असे.
# actual: त्यांपैकी काही ही अनमोल सणांच्या गोष्टी आपले सण आपले उत्सव लेखक श्रीकांत प्र.गोवंडे | Pred: त्यांपिकी काहीलही अन्मोळ सनांच्या वोष्ठी अपले सणापली उचवलेकक श्रेकांतप्र कोवणटे.
# actual: गमभन विषय तपासत नाही. | Pred: गमभणा विषेत पासत नाही.
# actual: केशवसुत कृष्णाजी केशव दामले | Pred: केशंसूत क्रष्णाळांजी केशंव दामले.
# actual: महाभारत हा भारतात लिहिला गेलेला एक प्राचीन ग्रंथ आहे. | Pred: महाभारथाच लिला गेलेला एक राचीन ग्रंध आहे.
# actual: त्याचे नाव त्याच्या आजोबांवरून ठेवण्यात आले होते. | Pred: त्याचे नाव त्याच्या अजवान वर्ण ठेऊण्यात वले होते.
# actual: लावणी च्या उत्पत्ती विषयी दोन स्वतंत्र विचारप्रवाह आहेत. | Pred: लाऊन चाळ उत्पतीमशे दुन स्वतंद्र विच्षात लवाहा आहे.
# actual: गुन्हे दाखल झाल्यानंतर टप्प्याटप्प्याने रक्कम भरली. | Pred: गुन्ही दाखल झालानंतर टप्प्या टप्प्यानी प्रकंभरली.
# actual: भारतीय क्रिकेट संघाकडून शतक ठोकणारे ते पहिले फलंदाज होते. | Pred: महाडतीय क्रीकेट संघाकळून व्षतक ठोकणारे ते पहिले वदंदाच होते.
# actual: त्यांची राजभाषा मल्याळी तमिळ मिश्रित होती. | Pred: त्यांची राजवाशा मल्ह्याळी तमेळी निष्टीत होती.
# actual: सत्यभामा कृष्णाची पत्नी होती. | Pred: सत्य भामा पुरुष्णाची पत्तीमी होती.
# actual: लक्षातच नाही राहत. | Pred: लक्षातच नाही राहत.
# actual: ही कसरत जो व्यवस्थित सांभाळतो तो भ्रष्ट. | Pred: ही कसरत जो व्यवस्थीत सामभाळतो तो भ्रष्ट
# actual: हिंदू धर्मात गंगा नदीला सर्वात पवित्र मानले आहे. | Pred: हिंचु धर्मात गंगानधीला सर्वात पवित्र मानले आहे.
# actual: काकींला तूझी खूप आठवण येते. | Pred: काकिल्यात उडडडी खूपाठवणी हेते.
# actual: तर स्त्री म्हणाली की मूल झालेच नाही. | Pred: तर स्वीमाणाली की मोन झालेच नाही.
# actual: दोघेही महान धनुर्धर झाले. | Pred: दोकीही महान धनुरधर चाले.
# actual: याला चक्री भजन असे नाव आहे. | Pred: याला चक्री भजन असे नावाही.
# actual: दुर्योधनाने त्याला अंग देशाचा राजा बनविले होते. | Pred: दुर्योधनाने त्याला अंगदेशाचा राजा वनविले होते.
# actual: लहान मुलांचा चंद्र म्हणजे त्यांचा मामा. | Pred: लहान मुलांचा चंद्र म्हणजे त्याचा मामा.
# actual: तिच्या सौंदर्याची स्तुती दूरवर पसरलेली होती. | Pred: तीच्या संदर्याची स्तुती दुरुवर पस्वर लेली होती.
# actual: पुस्तक पुण्याच्या देशमुख आणि कंपनीने प्रकाशित केले आहे. | Pred: पुद्ध पुण्याच्या दिश्मुख आणि कंपनिनी प्रकाशीत केले आहे.
# actual: हा खून हर्षाचा आहे. | Pred: हा खून हर्षात आहे.
# actual: एक हिंदू तुकाराम खरे नाव तात्या पडवळ | Pred: एक घिंदूतुकाराम खरे नाव ताथ्या पडवर
# actual: शेवग्याच्या पानांची भाजी चवदार लागते. | Pred: शेवग्याच्या पानांथी भाजी चओदार लागते.
# actual: राष्ट्रीय महामार्ग मुंबई नागपूर कोलकाता हा राष्ट्रीय महामार्ग अकोला जिल्ह्यातून जातो. | Pred: राष्ट्य महामार्ग मुंवय्नाक पूर कोलकाता हा प्राष्ट्य महामार्ग अकोला जिल्यातंचातो.
# actual: तिखटाची मात्रा लसणाने कमी जास्त करावी. | Pred: तिकटाची मातरा लस्नाने कमी जास्त करावी.
# actual: त्यानी ब्रह्मदेवाला प्रसन्न करून घेण्यासाठी कठोर तप केले. | Pred: त्यानी व्रम्मदिवाला प्रसंन करून घेण्यासाठी कठोळ तप केले.
# actual: उपचारांसाठी ते वेळोवेळी अमेरिकेला जाऊन आले. | Pred: उच्छारांचाठी ते वेळोवेळी अमिदिकेला जावून आले.
# actual: पुस्तकांची आवड असल्यामुळे घरातच खूप पुस्तके गोळा केली होती. | Pred: पुस्तकांची आवड असल्यामुळे घरातच खूप पुस्तके गोळा केली होती.
# actual: गण गण म्हणजे गणपतीला केलेले आवाहन. | Pred: गण गण म्हणचे गणपतीला केलेले आवाहण.
# actual: बाबांचा निरोप मिळताच त्यांनी सर्व कामे बाजूला ठेवली. | Pred: बाबांचा मिदो, मिळिटाच त्यांनी सर्व कामी बाजूला ठेवली.
# actual: गहू व बाजरी ही येथील प्रमुख पिके आहेत. | Pred: गहुव बाजरी ही एतील प्रमुख पिक्के आहेत.
# actual: ही वस्ती मध्य प्रदेशातील विदिशा जिल्हयातील रावणग्राम क्षेत्रात आहे. | Pred: ही वस्ती मध्ये प्रदेशातील विदिशा जिल्यातील रामण ग्राम शेतरात आहे.
# actual: परिस्थिती आहे त्यापेक्षा जास्त भयानक वाटू लागते. | Pred: परितिती आहे त्याविक्षा जाच्त भयांना क्वाटू लाकती.
# actual: आपण माणसांना भेटतो. | Pred: आपण मानसांना भिटतो.
# actual: त्यांच्यावर युद्धाचे अनेक प्रसंग आले. | Pred: त्यांच्यावर युद्धाचे अनेक प्रसंग आले.
# actual: भारतात हीच पद्धत आहे. | Pred: भारतात ही पद्दत आहे.
# actual: ते संत तुकाराम महाराजांना आपले गुरू मानीत. | Pred: ते संत तुकारा महाराजांना आपले गुरू मानीत.
# actual: चाटण या संस्कृत शब्दावरून चटणी हा शब्द भारतीय भाषांत आला. | Pred: साटण या संस्कृत शगदावरून चत्नी हा शब्द भारतीय भाषांत आला.
# actual: गिरिजाबाई हे त्यांच्या पत्नीचे नाव. | Pred: गिरीच्या बाई हे त्यांच्या पत्नीचे नाव.
# actual: पोस्टाचे तिकीट असलेल्या व्यक्ती | Pred: फोस्थ्याचे तिकित असलेल्या व्याती.
# actual: त्या जलातून गंगा उत्पन्न झाली. | Pred: त्या जलातून गंगा उचपन्न झाली.
# actual: चेन्नईचे चार मोठे भाग आहेत उत्तर, मध्य, दक्षिण आणि पश्चिम. | Pred: चन्नईचे चारमोठी भागाही, पुत्तर, मध्य, दक्षिड, आणि पच्षिड.
# actual: जड भरत भागवत पुराणामधील व्यक्ती. | Pred: जड, भरत, भागुवत, पुरणामधील व्यकती.
# actual: मागे या मांजरीचा उल्लेख मी केला आहे. | Pred: मागे या मांज्रीचा उदलेक मी केला आहे.
# actual: मिझो व इंग्रजी ह्या येथील प्रमुख भाषा आहेत. | Pred: मीजो व इंग्रजी या देखील प्रमुख भाषा आहेत.
# actual: त्यामुळे त्या अष्टमीला हा जन्मदिवस उत्साहाने साजरा होतो. | Pred: त्यामुळे त्या अश्टमिला हा जनमधीवस उत्साहानी साजरा होतो.
# actual: कित्तुर चिन्नमा ह्या राणीने दिलेला लढा प्रसिद्ध आहे. | Pred: कितूर चिग्नमा या राणिनी दिलेला लडा प्रसिद्ध आहे.
# actual: म्हणजेच यंत्रमागावर एक विणकर काम करीत असेल. | Pred: मणजेच यंत्र मागावर एक विणकर काम करीत असेल.
# actual: यामध्ये तमिळनाडू राज्याच्या विविध कलाप्रकारांचे सादरिकरण केले जाते. | Pred: यामध्ये तमिळ नाडू प्राज्याच्या विविविध्य कला प्रकारांचे साद्वीकरण केले जाटे.
# actual: बोलीभाषेतून भाषांच्या लिपी तयार झाल्या. | Pred: मोली भाषितून भाषांच्या लिपी तयार झाल्या.
# actual: याचा आकार चंद्राच्या एकूण आकाराच्या फक्त वीस आहे. | Pred: यात्रााकार चंद्राच्या एकुणाकाराच्या फक्तवीस आहे.
# actual: ही सनातनी व म्हणून अतिप्राचीन समजली गेली. | Pred: ही संनातनी व म्हणून अती प्राचीन समजली गेली.
# actual: हे लिंग तू स्वतः बाळग. | Pred: हे लिंग तुस्वता बाळग
# actual: दुर्दैवाने त्यांना आई वडिलांचा सहवास फार काळ लाभला नाही. | Pred: दुर्देवानी त्यांना आईवनलांचा सहवास फारकाळ लाबलानाही.
# actual: हा त्या काळातील परंपरेला दिलेला छेद होता. | Pred: हा त्या काळातील परंपरिला दिलेला छे दोता.
# actual: त्याची पूजा अर्चा होते. | Pred: त्याची पूजा अर्च्या होते.
# actual: प्रमुख जिल्हा रस्ता, इतर प्रमुख जिल्हा रस्ता, ग्रामीण रस्ता. | Pred: प्रमुख जिल्लारसता इतर प्रमुख जिल्लारसता ग्रामिण रसता.
# actual: ती काशी देशाच्या राजाची कन्या होती. | Pred: ती काशी देशाच्या राज्याची कर्ण्या होती.
# actual: परंतु या प्रकल्पांना अनेक मर्यादा असतात. | Pred: पर्ण तुख या प्रकल्पांना अनेक मादे यादा असतात.
# actual: कर्जाने मान नेहमी खाली होते. | Pred: कर्जांनी मान निहिमी खाली होते.
# actual: भाषाविषयक सल्ला व मदत उपलब्ध करून दिली जाते. | Pred: भाष्यावी शेयक, सल्ला व मदत पुपलब्ध करून दिदी जाते.
# actual: आजही महाराष्ट्रातल्या ग्रामीण भागात गोंधळ परंपरा पाहावयास मिळते. | Pred: आजही महाराष्ट्रातल्या ग्रामिण भागात गोंधळ परंपरा पहावयास मिळते.
# actual: एखाद्या ठिकाणाचा फक्त अभ्यास करणे म्हणजे भूगोल नव्हे. | Pred: एखाद्या ठिकाणाच्या फक्ता आबद्यास करणी म्हणची भूगोल लवे.
# actual: मग ती मुलावर प्रीति करून आनंदानें राहिली. | Pred: मक्ती मुलावर प्रितीकरून आनंदानी राहिली.
# actual: ती फिरत फिरत यमुना तीरावर आली. | Pred: ती शिरत शिरत यामुना ती रावर आली.
# actual: टप्पू सुलतान मुकुंद टाकसाळे | Pred: त्यपुसुळतान मुकुंदे टाकसाळे.
# actual: कन्नड संगीत व नृत्यही याच काळात विकसित झाले. | Pred: कन्नट, संगीत, पंडूच्धेही याच काळात विकसीद झाले.
# actual: युनेस्कोने हे गाव दत्तक घेतले आहे. | Pred: युनेच कोने हे गाव दत्तक घेतले आहे.
# actual: विजय मांजरेकर याचे वडील होत. | Pred: विजे माजरेकर याचे वडील होत.
# actual: अनेक दिशांनी चेन्नई वेगाने वाढते आहे. | Pred: अनेक दिशांनी चन्ने वेगाने वाडते आहे.
# actual: म्हणजे आम्हाला अधिक उत्साह वाटेल. | Pred: म्हणचे आमाला अधिक उस्थाह वाटेल.
# actual: राष्ट्रीय व धार्मिक सण आणि उत्सव लेखिका करुणा ढापरे | Pred: आज्टीय व धार्मिक सण आणि उस्सव देखिका करूनाड आप्रे.
# actual: राजकीय महामार्ग हे महामार्ग राज्य सरकारच्या अखत्यारीत येतात. | Pred: राजकीळ महामार्ग हे महामार्ग राज्य सर्काच्या अकत्यारीत येतात.
# actual: रचनाकालाच्या अभ्यासासाठी भाषेचे स्वरूप हा पायाभूत आधार आहे. | Pred: रच्चना कालाच्या अभ्यासासाठी भाषीची सुरू, हा पायाभूत आदार आहे.
# actual: या कार्यक्रमामध्ये सर्वाना अन्न दान केले जाते. | Pred: या कारेक्रमामध्ये सर्वाना अन्नदान केले जाते.
# actual: या रेषेत येणारी सर्व बेटे ही या पर्वतरांगेचा भाग आहे. | Pred: या रेशेत येणारी सर्वबेती ती या पर्वत रांगेचा भाग आहे.
# actual: या पदार्थांपासूनच नंतर चंद्राची निर्मिती झाली. | Pred: या पद्धातापासूनच नंतर चंद्राची निर्मिती झाली.
# actual: आईचे नाव रुक्मिणी होते. | Pred: आईचे नाव नुकमीनी होते.
# actual: तयार झालेले वादळ ज्या मार्गावरून प्रवास करते त्या मार्गावर वादळे होत रहातात. | Pred: तयार झालीली वादर जा मार्गावरून रबास करती त्या मार्गावर वादळे पोत गहातात.
# actual: अर्थात हा प्रतिमा दहन कार्यक्रम खूपच सीमित आहे. | Pred: अर्थात हा प्रद्धीमा दहन कारेक्रेम हुपच सिमी ताहे.
# actual: भारताने पहिला उपग्रह आकाशात पाठवला होता, त्याला आर्यभट्ट असे नाव दिले आहे. | Pred: भारताने पहिला उपगर्ह आकाशात पाठवला होता त्याला आर्य भट्टक असे नाव दिले आहे.
# actual: सरकारी अनूदानावर या शाळा चालतात. | Pred: सरकारी अमुदानावर या शाळाचालतात.
# actual: ह्या बेटाचा पश्चिम भाग हैती देशाने व्यापला आहे. | Pred: या बेटाचा पच्छिमभाक हईती देशानी व्यापला आहे.
# actual: त्यांच्या नावावर एक कसोटी बळीही आहे. | Pred: त्यांच्या मावावर एक कसोठी वरीही आहे.
# actual: यमुना ही गंगेची उपनदी स्वतःच एक स्वतंत्र आणि मोठी नदी आहे. | Pred: यमुणाही गंगेची उपनदी च्वताच एक स्वतंत्र आणि मोठी नदी आहे.
# actual: बांगलादेशात ती बंगालच्या उपसागरात मिळते. | Pred: बांगला दिशात, ती वंगारच्या उपसागरात मिळते.
# actual: वेळेपूर्वी मला मरायचे नाही आणि मेल्यावरही जगायचे आहे. | Pred: वेळेपूळ्वी माला मरायचे नाही आणि नेल्या वरही जगाईचे आहे.
# actual: येथील गरमपाण्याचे झरे हे एक प्रमुख आकर्षण आहे. | Pred: येथील गरम पाण्याचे झरे हे एक प्रमुख आपकाशन आहे.
# actual: गाडगेबाबांचे विचार एकदा गाडगेबाबा रस्त्याने जात असताना. | Pred: गाढगेबाबांची विच्चार एकदा गाढगेबाबा रस्त्यानी जात असताना.
# actual: नामदेव हे त्यांचेच पूर्वज असावेत. | Pred: नामदेव त्यांचीस पुर्वज असावेत.
# actual: नाना वांद्रेकर नारायण आठवले | Pred: नाना वांद्रेकर नारायणाठवले.
# actual: त्यांना रमेश माशेलकर या नावानेही ओळखले जाते. | Pred: त्यांना रमीश माशेलकर या नावानी ही ओळकले जाते.
# actual: लवकरच लिंकनच्या वडिलांनी सारा बुश जॉन्स्टन हिच्याशी दुसरा विवाह केला. | Pred: लउकरस लिंकनच्या वडीलांनी साराबूश जॉनस्चन किच्याशी दुसराविवाह केला.
# actual: नदी जीवनदायी आहे. | Pred: नदी जीवन दाही आहे.
# actual: हा एक गट आहे आणि तो सर्वांसाठी उपलब्ध आहे. | Pred: हाएक गटाहे आणितो सर्वांचाठी उपलब्ध आहे.
# actual: दारू पिणाऱ्या अनेक व्यक्तींमध्ये एखादा न पिणारा अडचणीचा ठरतो. | Pred: दारू पिणार्या आणि प्यक्तिंमध्ये एकादांना पिणारा अडसणीचा ठरतो.
# actual: या टीकेला उत्तर देणे संघाला जमले नाही. | Pred: या टीकेला उत्तर देणी संघाला जंगले नाही.
# actual: परिणामी विद्यार्थी नव्यानव्या कॢप्तिपूर्ण व कल्पक उपक्रमांमध्ये रस घेऊ लागले आहेत. | Pred: परे नामी विद्ध्यारतील नाव्या नव्याकृतीपूर्णवकल्प उपकरमांमध्येरस घेऊ लागले आहेत.
# actual: जीवनदान मिळालेले हे सरदार. | Pred: जीवंदान मिळालेली हे सरतार.
# actual: मी येईपर्यंत ते जमिनीवर ठेऊ नकोस हे सांगितले. | Pred: मी येई परंतती जमणीवर ठेवून अकोसे साणगीत लेई.
# actual: कावळा माणसाच्या वसाहतीजवळ पण घरात न येणारा, परिचित पक्षी आहे. | Pred: कावणा मांसाच्या वसाती जवळ पण घरात नईणारा पनिचीत पक्षिय आहे.
# actual: समुद्रकिनाऱ्यावर असल्यामुळे चेन्नईतील तापमानात मोठे फरक होत नाहीत. | Pred: समुद्र किंनारावर असल्यामुळे चेबने तिल तापमानात मोठे फरव होत नाहीत.
# actual: संकुलं मुंबईत विद्यापीठाची दोन संकुले आहेत. | Pred: संकून मुंबहीत विद्यापिटाची दोन संकुले आहे.
# actual: येथे प्रवेश करण्यासाठी शुल्क आहे. | Pred: येथे प्रवेश करण्यासाती शुलका आहे.
# actual: वादळ ही एक नैसर्गिक आपत्ती आहे. | Pred: वादळ वी एक नाईसर्गी कापत्ती आहे.
# actual: शिलाँग ही मेघालयची राजधानी व सर्वात मोठे शहर आहे. | Pred: शिल्हूंगी मेघालयाची राबतानी व सर्वात मोठे शहर आहे.
# actual: राजकीय विचार संघ स्वतःला सांस्कृतिक संघटन म्हणवून घेते. | Pred: राजखीय विच्यार संगस स्वताला सावस्पुतिक संगतद म्हणवेते.
# actual: त्यांनी तो स्वीकारला नाही. | Pred: त्यांनी तोच इकारला नाही.
# actual: कर्नाटक या नावाचे अनेक अर्थ आहेत. | Pred: कर्नाटिक्या नावाचे आदिकरता आहेत.

# %% [markdown]
# ## Fin!
#
# If you made it all the way till the end then pat yourself on the back. Looking back, we learned how to train *any* Whisper checkpoint faster, cheaper and with negligible loss in WER.
#
# With PEFT, you can also go beyond Speech recognition and apply the same set of techniques to other pretrained models as well. Come check it out here: https://github.com/huggingface/peft 🤗
#
# Don't forget to tweet your results and tag us! [@huggingface](https://twitter.com/huggingface) and [@reach_vb](https://twitter.com/reach_vb) ❤️

# %%
from transformers import (
    AutomaticSpeechRecognitionPipeline,
    WhisperForConditionalGeneration,
    WhisperTokenizer,
    WhisperProcessor,
)
from peft import PeftModel, PeftConfig

import librosa


peft_model_id = "Anudeep28/whisper-tiny-marathi-100steps" # Use the same model ID as before.
language = "mr"
task = "transcribe"
peft_config = PeftConfig.from_pretrained(peft_model_id)
model = WhisperForConditionalGeneration.from_pretrained(
    peft_config.base_model_name_or_path, load_in_8bit=True, device_map="auto"
)

model = PeftModel.from_pretrained(model, peft_model_id)
tokenizer = WhisperTokenizer.from_pretrained(peft_config.base_model_name_or_path, language=language, task=task)
processor = WhisperProcessor.from_pretrained(peft_config.base_model_name_or_path, language=language, task=task)
feature_extractor = processor.feature_extractor
forced_decoder_ids = processor.get_decoder_prompt_ids(language=language, task=task)
pipe = AutomaticSpeechRecognitionPipeline(model=model, tokenizer=tokenizer, feature_extractor=feature_extractor)
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.

# %%
# audio_path = 'marathi2.wav'
audio_path = 'marathi.mp3'
audio, original_sr = librosa.load(audio_path, sr=None)  # Load with original sampling rate

# %%
target_sr = 16000  # Target sampling rate
if original_sr != target_sr:
    audio = librosa.resample(audio, orig_sr=original_sr, target_sr=target_sr)

# %%
audio = audio / np.max(np.abs(audio))  # Normalize to [-1, 1]

# %%
input_features = processor(audio, sampling_rate=target_sr, return_tensors="pt").input_features

# %%
# Convert input features to the correct type
input_features = input_features.half()  # Convert to float16

# %%
# Generate transcription using the Whisper model
generated_ids = model.generate(
    input_features.to("cuda"),  # Directly pass input features
    max_length=model.config.max_length,
    num_beams=model.config.num_beams,
    early_stopping=True,
    num_return_sequences=1,
    forced_decoder_ids=forced_decoder_ids,
)

# %%
# Decode the generated IDs and print the transcription
transcription = tokenizer.decode(generated_ids[0], skip_special_tokens=True)
print(f"Transcription: {transcription}")
# Out:
# Transcription: आपला मजकूर ताहीप कराकीमा पेस्ट कराजामुळेतो आश्षे पेक्षा जास्थ आवाज भाषा आणि उच्चारांमध्ये सर्वाच संवाधात मजकूर्ते भाषणात रूपांतरेथ होयी.

# %% [markdown]
# #### Make the above modular for reuse

# %%
# imports
from transformers import (
    AutomaticSpeechRecognitionPipeline,
    WhisperForConditionalGeneration,
    WhisperTokenizer,
    WhisperProcessor,
)
from peft import PeftModel, PeftConfig

import librosa

# Getting the fine tuned model from my account
peft_model_id = "Anudeep28/whisper-tiny-marathi-100steps" # Use the same model ID as before.
language = "mr"
task = "transcribe"
peft_config = PeftConfig.from_pretrained(peft_model_id)
model = WhisperForConditionalGeneration.from_pretrained(
    peft_config.base_model_name_or_path, load_in_8bit=True, device_map="auto"
)

model = PeftModel.from_pretrained(model, peft_model_id)
tokenizer = WhisperTokenizer.from_pretrained(peft_config.base_model_name_or_path, language=language, task=task)
processor = WhisperProcessor.from_pretrained(peft_config.base_model_name_or_path, language=language, task=task)
feature_extractor = processor.feature_extractor
forced_decoder_ids = processor.get_decoder_prompt_ids(language=language, task=task)
pipe = AutomaticSpeechRecognitionPipeline(model=model, tokenizer=tokenizer, feature_extractor=feature_extractor)
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.

# %%
def transcribe_speech(audio_path, model, processor, target_sr, forced_decoder_ids):
    

    # audio_path = 'marathi2.wav'
    audio_path = audio_path
    audio, original_sr = librosa.load(audio_path, sr=None)  # Load with original sampling rate

    # target_sr = 16000  # Target sampling rate
    if original_sr != target_sr:
        audio = librosa.resample(audio, orig_sr=original_sr, target_sr=target_sr)
    
    audio = audio / np.max(np.abs(audio))  # Normalize to [-1, 1]

    # Convert the input features to mel-spectram
    input_features = processor(audio, sampling_rate=target_sr, return_tensors="pt").input_features

    # Convert input features to the correct type
    input_features = input_features.half()  # Convert to float16

    # Generate transcription using the Whisper model
    generated_ids = model.generate(
        input_features.to("cuda"),  # Directly pass input features
        max_length=model.config.max_length,
        num_beams=model.config.num_beams,
        early_stopping=True,
        num_return_sequences=1,
        forced_decoder_ids=forced_decoder_ids,
    )

    # Decode the generated IDs and print the transcription
    transcription = tokenizer.decode(generated_ids[0], skip_special_tokens=True)
    print(f"Transcription: {transcription}")

    return transcription

# %%
text = transcribe_speech(audio_path="marathi2.wav", model=model,
                  processor=processor,
                  target_sr=16000,
                  forced_decoder_ids=forced_decoder_ids)
# Out:
# c:\Users\PC\Documents\Speech2Text\myenv\lib\site-packages\transformers\generation\configuration_utils.py:615: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# Transcription: मुंबईही भारताची आर्थिक व मनुरंजनाची राजधान याही. रिजर्वब्यांक मुंबईशेर बाजार राष्ट्रीय शेर बाजार या महत्त्वाच्या आर्थिक संस्था या शहरात आहेत.

# %%
text
# Out:
# 'मुंबईही भारताची आर्थिक व मनुरंजनाची राजधान याही. रिजर्वब्यांक मुंबईशेर बाजार राष्ट्रीय शेर बाजार या महत्त्वाच्या आर्थिक संस्था या शहरात आहेत.'
